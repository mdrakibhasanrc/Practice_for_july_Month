# %% [markdown]
# # Project: Customer Shopping Dataset - Retail Sales Data

# %% [markdown]
# About Dataset:
#  Welcome to the shopping world of Istanbul! Our dataset contains shopping information from 10 different shopping malls between 2021 and 2023. We have gathered data from various age groups and genders to provide a comprehensive view of shopping habits in Istanbul. The dataset includes essential information such as invoice numbers, customer IDs, age, gender, payment methods, product categories, quantity, price, order dates, and shopping mall locations. We hope that this dataset will serve as a valuable resource for researchers, data analysts, and machine learning enthusiasts who want to gain insights into shopping trends and patterns in Istanbul. Explore the dataset and discover the fascinating world of Istanbul shopping!

# %% [markdown]
# # Columns Description:

# %% [markdown]
# invoice_no: Invoice number. Nominal. A combination of the letter 'I' and a 6-digit integer uniquely assigned to each operation.
#
# customer_id: Customer number. Nominal. A combination of the letter 'C' and a 6-digit integer uniquely assigned to each operation.
#
# gender: String variable of the customer's gender.
#
# age: Positive Integer variable of the customers age.
#
# category: String variable of the category of the purchased product.
#
# quantity: The quantities of each product (item) per transaction. Numeric.
#
# price: Unit price. Numeric. Product price per unit in Turkish Liras (TL).
#
# payment_method: String variable of the payment method (cash, credit card or debit card) used for the transaction.
#
# invoice_date: Invoice date. The day when a transaction was generated.
#
# shopping_mall: String variable of the name of the shopping mall where the transaction was made.

# %% [markdown]
# # Import Library:

# %% [markdown]
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# %matplotlib inline
# import warnings
# warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Collection from Kaggle

# %%
df=pd.read_csv('customer_shopping_data.csv')
df
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %% [markdown]
# # Understand Data

# %%
# to see my first five rows
df.head(5)
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %%
# to see my last five rows
df.tail(5)
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 99452    Credit Card   21/09/2022            Kanyon
# 99453           Cash   22/09/2021    Forum Istanbul
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul

# %%
# to see my sample five rows
df.sample(5)
# Out:
#       invoice_no customer_id  gender  age   category  quantity   price  \
# 15473    I256687     C102313    Male   22  Cosmetics         2   81.32
# 6926     I234118     C839012  Female   57   Clothing         2  600.16
# 61613    I119252     C156641    Male   44      Books         3   45.45
# 37884    I335380     C225095    Male   51       Toys         2   71.68
# 547      I332003     C299787  Female   30  Cosmetics         2   81.32
#
#       payment_method invoice_date     shopping_mall
# 15473     Debit Card    9/11/2021            Kanyon
# 6926            Cash   13/11/2022      Zorlu Center
# 61613    Credit Card    10/5/2022  Mall of Istanbul
# 37884           Cash   13/08/2021    Viaport Outlet
# 547      Credit Card   16/12/2021       Cevahir AVM

# %%
# to see basic info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB

# %%
# to see data shape
df.shape
# Out:
# (99457, 10)

# %%
# to see columns name
df.columns
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'age', 'category', 'quantity',
#        'price', 'payment_method', 'invoice_date', 'shopping_mall'],
#       dtype='object')

# %%
# to see data type
df.dtypes
# Out:
# invoice_no         object
# customer_id        object
# gender             object
# age                 int64
# category           object
# quantity            int64
# price             float64
# payment_method     object
# invoice_date       object
# shopping_mall      object
# dtype: object

# %%
# to see basic statisticd
df.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    689.256321
# std       14.990054      1.413025    941.184567
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %% [markdown]
# # Exploratory Data Analysis

# %%
# to see duplicated value
df.duplicated().sum()
# Out:
# 0

# %%
# to see null values
df.isnull().sum()
# Out:
# invoice_no        0
# customer_id       0
# gender            0
# age               0
# category          0
# quantity          0
# price             0
# payment_method    0
# invoice_date      0
# shopping_mall     0
# dtype: int64

# %%
# to see ploting null values
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
plt.title('Missing value plotting');

# %%
# change columns name
df.rename(columns={'invoice_date':'date'},inplace=True)

# %%
# change data tyep
df['date']=pd.to_datetime(df['date'])

# %%
# extract some columns from date columns
df['Year']=df['date'].dt.year
df['Month_Name']=df['date'].dt.month_name()
df['Day_Name']=df['date'].dt.day_name()
df['Quarter']=df['date'].dt.quarter

# %%
df['year']=df['year'].astype('int')

# %%
df['Revenue']=df['price']*df['quantity']

# %%
df=df.rename(columns=str.lower)

# %%
# Rearrange Data
df=df[['invoice_no','customer_id','date','year','gender','age','category','payment_method','shopping_mall','month_name','day_name','quarter','quantity','price','revenue']]

# %%
df.head(5)
# Out:
#   invoice_no customer_id       date  year  gender  age  category  \
# 0    I138884     C241288 2022-05-08  2022  Female   28  Clothing
# 1    I317333     C111565 2021-12-12  2021    Male   21     Shoes
# 2    I127801     C266599 2021-09-11  2021    Male   20  Clothing
# 3    I173702     C988172 2021-05-16  2021  Female   66     Shoes
# 4    I337046     C189076 2021-10-24  2021  Female   53     Books
#
#   payment_method   shopping_mall month_name  day_name  quarter  quantity  \
# 0    Credit Card          Kanyon        May    Sunday        2         5
# 1     Debit Card  Forum Istanbul   December    Sunday        4         3
# 2           Cash       Metrocity  September  Saturday        3         1
# 3    Credit Card    Metropol AVM        May    Sunday        2         5
# 4           Cash          Kanyon    October    Sunday        4         4
#
#      price   revenue
# 0  1500.40   7502.00
# 1  1800.51   5401.53
# 2   300.08    300.08
# 3  3000.85  15004.25
# 4    60.60    242.40

# %%
df=df.rename(columns=str.lower)

# %%
cat=df.select_dtypes(include='object').columns

# %%
num=df.select_dtypes(exclude='object').columns

# %%
cat
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'category', 'payment_method',
#        'shopping_mall', 'month_name', 'day_name'],
#       dtype='object')

# %%
num
# Out:
# Index(['date', 'year', 'age', 'quarter', 'quantity', 'price', 'revenue'], dtype='object')

# %% [markdown]
# ## Data Visulization

# %% [markdown]
# ### KPI

# %%
# total revenue
print(f"Total Revenue is {round(df['revenue'].sum(),2)}")
# Out:
# Total Revenue is 251505794.25

# %%
# total Quantity 
print(f"Total Quantity is {round(df['quantity'].sum(),2)}")
# Out:
# Total Quantity is 298712

# %%
# total order count
print(f"Total Quantity is {round(df['quantity'].count(),2)}")
# Out:
# Total Quantity is 99457

# %% [markdown]
# ## Answer Some Business Question

# %% [markdown]
# ### What is the distribution of customers by gender?

# %%
plt.figure(figsize=(10,6))
ax=sns.countplot(data=df,x=df['gender'],palette='mako_r')
ax.bar_label(ax.containers[0])
plt.title('distribution of customers by gender');

# %% [markdown]
# ### What is the average age of customers?

# %%
print(f"Average age of Customer is {df['age'].mean()}")
# Out:
# Average age of Customer is 43.42708909377922

# %% [markdown]
# ### Which category of products is the most popular?

# %%
plt.figure(figsize=(10,6))
ax=sns.countplot(data=df,x=df['category'],palette='mako_r',order=df['category'].value_counts().index)
ax.bar_label(ax.containers[0])
plt.title('distribution of customers by category');

# %% [markdown]
# ### What is the distribution of purchases across different categories?

# %%
plt.figure(figsize=(10,6))
ax=df.groupby('category')['revenue'].sum().plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.title('Category by Revenue');

# %% [markdown]
# ### What are the most common payment methods used by customers?

# %%
df['payment_method'].value_counts()
# Out:
# Cash           44447
# Credit Card    34931
# Debit Card     20079
# Name: payment_method, dtype: int64

# %%
plt.figure(figsize=(15,6))
df['payment_method'].value_counts().plot(kind='pie',autopct="%1.2f%%",colors=sns.set_palette('mako_r'))
plt.title('most common payment methods used by customers',fontsize=14);

# %% [markdown]
# ### Is there any correlation between payment method and the amount spent?

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='payment_method', y='revenue')

# Add labels and title
plt.xlabel('Payment Method')
plt.ylabel('Revenue')
plt.title('Correlation between Payment Method and Revenue');

# %% [markdown]
# # Which shopping mall has the highest number of transactions?

# %%
plt.figure(figsize=(10,6))
ax=sns.countplot(data=df,x=df['shopping_mall'],palette='mako_r',order=df['shopping_mall'].value_counts().index)
ax.bar_label(ax.containers[0])
plt.title('shopping mall has the highest number of transactions')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %% [markdown]
# ### Does the choice of shopping mall influence the total revenue?

# %%
df.groupby('shopping_mall')['revenue'].sum()
# Out:
# shopping_mall
# Cevahir AVM          12645138.20
# Emaar Square Mall    12406100.29
# Forum Istanbul       12303921.24
# Istinye Park         24618827.68
# Kanyon               50554231.10
# Mall of Istanbul     50872481.68
# Metrocity            37302787.33
# Metropol AVM         25379913.19
# Viaport Outlet       12521339.72
# Zorlu Center         12901053.82
# Name: revenue, dtype: float64

# %%
plt.figure(figsize=(10,6))
color=sns.set_palette('mako_r')
ax = sns.barplot(data=df.groupby('shopping_mall')['revenue'].sum().reset_index(), x='shopping_mall', y='revenue', palette='mako_r')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.title('Shopping Mall by Total Revenue');

# %% [markdown]
# ### Is there a day  of the weekand month that tends to have higher sales?

# %%
df.groupby('day_name')['revenue'].sum()
# Out:
# day_name
# Friday       36461538.67
# Monday       37578624.06
# Saturday     36509126.88
# Sunday       34130252.87
# Thursday     35679669.44
# Tuesday      35510654.19
# Wednesday    35635928.14
# Name: revenue, dtype: float64

# %%
plt.figure(figsize=(12,6))
ax=sns.barplot(data=df.groupby('day_name')['revenue'].sum().reset_index(),x='day_name',y='revenue',palette='mako_r')
plt.title('Day_Name by Total Revenue');

# %%
plt.figure(figsize=(12,6))
ax=sns.lineplot(data=df.groupby('day_name')['revenue'].sum().reset_index(),x='day_name',y='revenue',palette='mako_r',marker='*',sizes=5)
plt.title('Day_Name by Total Revenue Trends');

# %%
plt.figure(figsize=(12,6))
ax=sns.lineplot(data=df.groupby('month_name')['revenue'].sum().reset_index(),x='month_name',y='revenue',palette='mako_r',marker='*',sizes=5)
plt.title('month_Name by Total Revenue Trends');

# %%
plt.figure(figsize=(12,6))
ax=sns.lineplot(data=df.groupby('year')['revenue'].sum().reset_index(),x='year',y='revenue',palette='mako_r',marker='*',sizes=5)
plt.title('year by Total Revenue Trends');

# %% [markdown]
# ### Are there any outliers in terms of quantity or price?

# %%
fig,ax=plt.subplots(1,2,figsize=(10,5))
sns.boxplot(y=df['quantity'],ax=ax[0])
ax[0].set_title('quantity Outlier')
plt.xlabel('quantity')

sns.boxplot(y=df['price'],ax=ax[1])
ax[1].set_title('price Outlier')
plt.xlabel('price');

# %% [markdown]
# ### How does revenue vary across different quarters of the year?

# %%
data=df.groupby(['year','quarter'])['revenue'].sum()
data
# Out:
# year  quarter
# 2021  1          28185427.75
#       2          28982988.40
#       3          28546353.01
#       4          28845801.43
# 2022  1          28374496.09
#       2          29246224.88
#       3          28673976.23
#       4          29142116.88
# 2023  1          14002018.13
#       2           3083696.86
#       3           2561878.28
#       4           1860816.31
# Name: revenue, dtype: float64

# %%
plt.figure(figsize=(15,6))
ax=data.plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.title('revenue vary across different quarters of the year');

# %% [markdown]
# ### Is there any correlation between age and spending habits?

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df,x=df['age'],y=df['revenue'])
plt.title('correlation between age and spending habits');

# %%
pd.crosstab(df.gender,df.category).reset_index()
# Out:
# category  gender  Books  Clothing  Cosmetics  Food & Beverage  Shoes  \
# 0         Female   2906     20652       9070             8804   5967
# 1           Male   2075     13835       6027             5972   4067
#
# category  Souvenir  Technology  Toys
# 0             3017        2981  6085
# 1             1982        2015  4002

# %%
plt.figure(figsize=(12,6))
pd.crosstab(df.gender,df.category).plot(kind='bar',stacked=True);

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=df,y=df['gender'],x=df['revenue'])
plt.title('violinplot');

# %% [markdown]
# ### Categorical Columns vs Revenue

# %%
# create function
def cat_chart(feature):
    
    fig,ax=plt.subplots(1,2,figsize=(12,6))
    sns.set_palette("tab10")
    sns.countplot(data=df,x=df[feature],palette='mako_r',ax=ax[0])
    ax[0].bar_label(ax[0].containers[0])
    ax[0].set_title(f"{feature} Count")
    ax[0].set_xticklabels(ax[0].get_xticklabels(),rotation=90)
    
    #sns.barplot(data=df,x=df[feature],y=df['revenue'],palette='mako_r',ax=ax[1])
    df.groupby(feature)['revenue'].sum().plot(kind='bar',ax=ax[1])
    #ax[1].bar_label(ax[1].containers[0])
    ax[1].set_title(f"{feature} by Revenue")
    ax[1].set_xticklabels(ax[1].get_xticklabels(),rotation=90)

# %%
cat_chart('gender')

# %%
cat_chart('category')

# %%
cat_chart('payment_method')

# %%
cat_chart('month_name')

# %%
cat_chart('day_name')

# %%
cat_chart('shopping_mall')

# %% [markdown]
# # Numerical Columns and Numerical columns vs Revenue Analysis

# %%
# create function
def num_chart(feature):
    
    fig,ax=plt.subplots(1,3,figsize=(18,6))
    sns.set_palette("tab10")
    sns.histplot(data=df,x=df[feature],ax=ax[0],kde=True)
    ax[0].set_title(f"{feature} distribution")
    
    sns.boxplot(data=df,x=df[feature],palette='mako_r',ax=ax[1])
    ax[1].set_title(f"{feature} boxplot")
    
    sns.scatterplot(data=df,x=df[feature],y=df['revenue'],ax=ax[2])
    ax[2].set_title(f"{feature} by Revenue Scatterplot")

# %%
num_chart('revenue')

# %%
num_chart('quantity')

# %%
num_chart('age')

# %%
num_chart('price')

# %%
num_chart('quarter')

# %% [markdown]
# # correlation

# %%
corr=df.corr()
corr
# Out:
#               year       age   quarter  quantity     price   revenue
# year      1.000000 -0.002390 -0.144897  0.000821 -0.000831  0.000576
# age      -0.002390  1.000000  0.005929  0.000667  0.001694  0.002731
# quarter  -0.144897  0.005929  1.000000  0.004273 -0.002827 -0.001621
# quantity  0.000821  0.000667  0.004273  1.000000  0.344880  0.461173
# price    -0.000831  0.001694 -0.002827  0.344880  1.000000  0.962372
# revenue   0.000576  0.002731 -0.001621  0.461173  0.962372  1.000000

# %%
plt.figure(figsize=(13,6))
sns.heatmap(corr,cmap='viridis',annot=True,fmt='.2f')
plt.title('Correlation for each columns');

# %%
# Multivariate
sns.pairplot(df)
